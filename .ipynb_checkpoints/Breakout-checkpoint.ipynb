# %%
import numpy as np

import gym
from baselines.common.atari_wrappers import *

import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from dqn_agent import Agent

from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %config InlineBackend.figure_format='retina'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# loading the environment 
env = gym.make('Breakout-v0')
# Out:
# /home/parminder0407/anaconda3/envs/cv3/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
# using openai atari wrappers for preprocessing the input game image and stack frames
pp_env = wrap_deepmind(env,frame_stack=True)

# %%
# lets see the difference between the original and preprocessed game state

orig_state = env.reset()
pp_state = np.array(pp_env.reset())

fig,ax = plt.subplots(nrows=1,ncols=2)

# orig game state
ax[0].imshow(orig_state)
ax[0].set_title('Original game state')
print ("Original game state shape: {}".format(orig_state.shape))

# processed game state
ax[1].imshow(pp_state[:,:,0],cmap='gray')
ax[1].set_title('first frame of processed game state')
print ("Processed game state shape: {}".format(pp_state.shape))

plt.tight_layout()
plt.show()
# Out:
# Original game state shape: (210, 160, 3)
# Processed game state shape: (84, 84, 4)

# %%
random_rewards = []

for _ in range(1):
    # lets play a random game
    state = pp_env.reset()
    done = False
    total_reward = 0
    step = 0
    while not done:
        action = pp_env.action_space.sample()
        next_state,reward,done,_ = pp_env.step(action)
        
        # print step details
        print ("step: {}\t action: {}\t reward: {}\t done: {}".format(step,action,reward,done))
        # update state and total reward
        state = next_state
        total_reward += reward
        step+=1
    
    random_rewards.append(total_reward)

print ("Avg reward for random play episode: {}".format(np.mean(random_rewards)))
# Out:
# step: 0	 action: 2	 reward: 0.0	 done: False
# step: 1	 action: 0	 reward: 0.0	 done: False
# step: 2	 action: 3	 reward: 0.0	 done: False
# step: 3	 action: 0	 reward: 0.0	 done: False
# step: 4	 action: 3	 reward: 0.0	 done: False
# step: 5	 action: 2	 reward: 0.0	 done: False
# step: 6	 action: 2	 reward: 0.0	 done: False
# step: 7	 action: 2	 reward: 0.0	 done: False
# step: 8	 action: 3	 reward: 0.0	 done: False
# step: 9	 action: 1	 reward: 0.0	 done: False
# step: 10	 action: 0	 reward: 0.0	 done: False
# step: 11	 action: 3	 reward: 0.0	 done: False
# step: 12	 action: 1	 reward: 0.0	 done: False
# step: 13	 action: 0	 reward: 0.0	 done: False
# step: 14	 action: 3	 reward: 0.0	 done: False
# step: 15	 action: 3	 reward: 0.0	 done: False
# step: 16	 action: 3	 reward: 0.0	 done: False
# step: 17	 action: 2	 reward: 0.0	 done: False
# step: 18	 action: 1	 reward: 0.0	 done: False
# step: 19	 action: 0	 reward: 0.0	 done: False
# step: 20	 action: 1	 reward: 0.0	 done: False
# step: 21	 action: 2	 reward: 0.0	 done: False
# step: 22	 action: 3	 reward: 0.0	 done: False
# step: 23	 action: 3	 reward: 0.0	 done: False
# step: 24	 action: 1	 reward: 0.0	 done: False
# step: 25	 action: 3	 reward: 0.0	 done: False
# step: 26	 action: 3	 reward: 0.0	 done: False
# step: 27	 action: 3	 reward: 0.0	 done: False
# step: 28	 action: 0	 reward: 0.0	 done: False
# step: 29	 action: 0	 reward: 0.0	 done: False
# step: 30	 action: 0	 reward: 0.0	 done: False
# step: 31	 action: 3	 reward: 0.0	 done: False
# step: 32	 action: 2	 reward: 0.0	 done: False
# step: 33	 action: 2	 reward: 0.0	 done: False
# step: 34	 action: 1	 reward: 0.0	 done: False
# step: 35	 action: 3	 reward: 0.0	 done: False
# step: 36	 action: 1	 reward: 0.0	 done: False
# step: 37	 action: 2	 reward: 0.0	 done: False
# step: 38	 action: 3	 reward: 0.0	 done: False
# step: 39	 action: 3	 reward: 0.0	 done: False
# step: 40	 action: 1	 reward: 0.0	 done: False
# step: 41	 action: 0	 reward: 0.0	 done: False
# step: 42	 action: 2	 reward: 0.0	 done: False
# step: 43	 action: 2	 reward: 0.0	 done: False
# step: 44	 action: 0	 reward: 0.0	 done: False
# step: 45	 action: 1	 reward: 0.0	 done: False
# step: 46	 action: 1	 reward: 0.0	 done: False
# step: 47	 action: 3	 reward: 0.0	 done: False
# step: 48	 action: 0	 reward: 0.0	 done: False
# step: 49	 action: 3	 reward: 0.0	 done: False
# step: 50	 action: 2	 reward: 0.0	 done: False
# step: 51	 action: 3	 reward: 0.0	 done: False
# step: 52	 action: 0	 reward: 0.0	 done: False
# step: 53	 action: 2	 reward: 0.0	 done: False
# step: 54	 action: 2	 reward: 0.0	 done: False
# step: 55	 action: 2	 reward: 0.0	 done: False
# step: 56	 action: 3	 reward: 0.0	 done: False
# step: 57	 action: 2	 reward: 0.0	 done: False
# step: 58	 action: 3	 reward: 0.0	 done: False
# step: 59	 action: 3	 reward: 0.0	 done: False
# step: 60	 action: 3	 reward: 0.0	 done: False
# step: 61	 action: 1	 reward: 0.0	 done: False
# step: 62	 action: 3	 reward: 0.0	 done: False
# step: 63	 action: 2	 reward: 0.0	 done: False
# step: 64	 action: 1	 reward: 0.0	 done: False
# step: 65	 action: 3	 reward: 0.0	 done: False
# step: 66	 action: 3	 reward: 0.0	 done: False
# step: 67	 action: 1	 reward: 0.0	 done: False
# step: 68	 action: 1	 reward: 0.0	 done: False
# step: 69	 action: 2	 reward: 0.0	 done: False
# step: 70	 action: 3	 reward: 0.0	 done: False
# step: 71	 action: 2	 reward: 0.0	 done: False
# step: 72	 action: 1	 reward: 0.0	 done: False
# step: 73	 action: 1	 reward: 0.0	 done: False
# step: 74	 action: 2	 reward: 0.0	 done: False
# step: 75	 action: 2	 reward: 0.0	 done: False
# step: 76	 action: 2	 reward: 0.0	 done: False
# step: 77	 action: 3	 reward: 0.0	 done: False
# step: 78	 action: 1	 reward: 0.0	 done: False
# step: 79	 action: 2	 reward: 0.0	 done: False
# step: 80	 action: 0	 reward: 0.0	 done: False
# step: 81	 action: 3	 reward: 0.0	 done: False
# step: 82	 action: 2	 reward: 0.0	 done: False
# step: 83	 action: 0	 reward: 0.0	 done: False
# step: 84	 action: 3	 reward: 0.0	 done: False
# step: 85	 action: 1	 reward: 0.0	 done: False
# step: 86	 action: 1	 reward: 0.0	 done: False
# step: 87	 action: 3	 reward: 0.0	 done: False
# step: 88	 action: 0	 reward: 0.0	 done: False
# step: 89	 action: 1	 reward: 0.0	 done: False
# step: 90	 action: 3	 reward: 0.0	 done: False
# step: 91	 action: 3	 reward: 0.0	 done: False
# step: 92	 action: 3	 reward: 0.0	 done: False
# step: 93	 action: 3	 reward: 0.0	 done: False
# step: 94	 action: 2	 reward: 0.0	 done: False
# step: 95	 action: 1	 reward: 0.0	 done: False
# step: 96	 action: 2	 reward: 0.0	 done: False
# step: 97	 action: 2	 reward: 0.0	 done: False
# step: 98	 action: 3	 reward: 0.0	 done: False
# step: 99	 action: 1	 reward: 0.0	 done: False
# step: 100	 action: 0	 reward: 0.0	 done: False
# step: 101	 action: 3	 reward: 0.0	 done: False
# step: 102	 action: 1	 reward: 0.0	 done: False
# step: 103	 action: 0	 reward: 0.0	 done: False
# step: 104	 action: 1	 reward: 0.0	 done: False
# step: 105	 action: 3	 reward: 0.0	 done: False
# step: 106	 action: 0	 reward: 0.0	 done: False
# step: 107	 action: 3	 reward: 0.0	 done: False
# step: 108	 action: 3	 reward: 0.0	 done: False
# step: 109	 action: 3	 reward: 0.0	 done: False
# step: 110	 action: 1	 reward: 0.0	 done: False
# step: 111	 action: 2	 reward: 0.0	 done: False
# step: 112	 action: 3	 reward: 0.0	 done: False
# step: 113	 action: 3	 reward: 0.0	 done: False
# step: 114	 action: 1	 reward: 0.0	 done: False
# step: 115	 action: 0	 reward: 0.0	 done: False
# step: 116	 action: 1	 reward: 0.0	 done: False
# step: 117	 action: 1	 reward: 0.0	 done: False
# step: 118	 action: 3	 reward: 0.0	 done: False
# step: 119	 action: 2	 reward: 0.0	 done: False
# step: 120	 action: 2	 reward: 0.0	 done: False
# step: 121	 action: 2	 reward: 0.0	 done: False
# step: 122	 action: 3	 reward: 0.0	 done: False
# step: 123	 action: 3	 reward: 0.0	 done: False
# step: 124	 action: 2	 reward: 0.0	 done: False
# step: 125	 action: 1	 reward: 0.0	 done: False
# step: 126	 action: 0	 reward: 0.0	 done: False
# step: 127	 action: 0	 reward: 0.0	 done: False
# step: 128	 action: 2	 reward: 0.0	 done: False
# step: 129	 action: 0	 reward: 0.0	 done: False
# step: 130	 action: 1	 reward: 0.0	 done: False
# step: 131	 action: 1	 reward: 0.0	 done: False
# step: 132	 action: 1	 reward: 0.0	 done: False
# step: 133	 action: 1	 reward: 0.0	 done: False
# step: 134	 action: 3	 reward: 0.0	 done: False
# step: 135	 action: 1	 reward: 0.0	 done: False
# step: 136	 action: 0	 reward: 0.0	 done: False
# step: 137	 action: 3	 reward: 0.0	 done: False
# step: 138	 action: 1	 reward: 0.0	 done: False
# step: 139	 action: 0	 reward: 0.0	 done: False
# step: 140	 action: 2	 reward: 0.0	 done: False
# step: 141	 action: 0	 reward: 0.0	 done: False
# step: 142	 action: 0	 reward: 0.0	 done: False
# step: 143	 action: 1	 reward: 0.0	 done: False
# step: 144	 action: 1	 reward: 0.0	 done: False
# step: 145	 action: 1	 reward: 0.0	 done: False
# step: 146	 action: 3	 reward: 0.0	 done: False
# step: 147	 action: 0	 reward: 0.0	 done: False
# step: 148	 action: 3	 reward: 0.0	 done: False
# step: 149	 action: 0	 reward: 0.0	 done: False
# step: 150	 action: 1	 reward: 0.0	 done: False
# step: 151	 action: 1	 reward: 0.0	 done: False
# step: 152	 action: 0	 reward: 0.0	 done: False
# step: 153	 action: 2	 reward: 0.0	 done: False
# step: 154	 action: 1	 reward: 0.0	 done: False
# step: 155	 action: 3	 reward: 0.0	 done: False
# step: 156	 action: 0	 reward: 0.0	 done: False
# step: 157	 action: 1	 reward: 0.0	 done: False
# step: 158	 action: 3	 reward: 0.0	 done: False
# step: 159	 action: 0	 reward: 0.0	 done: False
# step: 160	 action: 1	 reward: 0.0	 done: False
# step: 161	 action: 1	 reward: 0.0	 done: False
# step: 162	 action: 3	 reward: 0.0	 done: False
# step: 163	 action: 2	 reward: 0.0	 done: False
# step: 164	 action: 3	 reward: 0.0	 done: False
# step: 165	 action: 2	 reward: 0.0	 done: False
# step: 166	 action: 3	 reward: 0.0	 done: False
# step: 167	 action: 1	 reward: 0.0	 done: False
# step: 168	 action: 0	 reward: 0.0	 done: False
# step: 169	 action: 2	 reward: 0.0	 done: False
# step: 170	 action: 0	 reward: 0.0	 done: False
# step: 171	 action: 1	 reward: 0.0	 done: False
# step: 172	 action: 1	 reward: 0.0	 done: False
# step: 173	 action: 3	 reward: 0.0	 done: False
# step: 174	 action: 3	 reward: 0.0	 done: False
# step: 175	 action: 2	 reward: 0.0	 done: False
# step: 176	 action: 1	 reward: 0.0	 done: False
# step: 177	 action: 1	 reward: 0.0	 done: False
# step: 178	 action: 1	 reward: 0.0	 done: False
# step: 179	 action: 2	 reward: 0.0	 done: False
# step: 180	 action: 1	 reward: 0.0	 done: False
# step: 181	 action: 0	 reward: 0.0	 done: False
# step: 182	 action: 2	 reward: 0.0	 done: False
# step: 183	 action: 1	 reward: 0.0	 done: False
# step: 184	 action: 1	 reward: 0.0	 done: True
# Avg reward for random play episode: 0.0

# %%
# initialising the agent
agent = Agent(state_shape=pp_env.observation_space.shape, action_size=pp_env.action_space.n,lr=2.5e-4)

from dqn_agent import REPLAY_START_SIZE

def evaluate_agent(agent):
    eval_score_list = []
    for _ in range(10):
        state = pp_env.reset()
        done = False
        eval_reward = 0
        while not done:
            action = agent.act(state,eps=0.1)
            next_state,reward,done,_ = pp_env.step(action)

            state = next_state
            eval_reward += reward
        eval_score_list.append(eval_reward)
    
    return np.mean(eval_score_list)

# training function
def dqn_train(max_episodes=1000,max_t=1000,eps_start=1.0,eps_end=1e-1,PRINT_EVERY=100):
    """
    trains the DQN agent

    Params
    ======
    max_episodes : max number of episodes for training the agent
    max_t : max number of timesteps for each episode to be used in training
    eps_start : starting value of epsilon
    eps_end : final value of epsilon

    """
    ACTION_EVERY = 4
    UPDATE_EVERY = 4
    MAX_EXPLORATION_FRAMES = 1e4
    
    eps_decay = np.exp(np.log(eps_end/eps_start)/MAX_EXPLORATION_FRAMES)
    
    eps = eps_start
    scores = []
    score_window = deque(maxlen=100)
    avg_scores = []

    for episode_count in range(1,max_episodes+1):

        # reset env state
        state = pp_env.reset()
        
        t_action = 0
        t_update = 0
        
        total_reward = 0
        for t in range(max_t) :
            if t_action == 0:
                # choose action using the local q-network
                action = agent.act(state,eps)
                
                # taking action in the env
                next_state,reward,done,_ = pp_env.step(action)

                # using agent to perform a learning step and save the sample in the memory
                agent.step(state,action,reward,next_state,done,t_update)

                # decay the epsilon value
                if len(agent.memory) > REPLAY_START_SIZE:
                    eps = max(eps_decay*eps,eps_end)
                
                # Update t_update
                t_update = (t_update+1) % UPDATE_EVERY
            
            else:
                # taking action in the env
                next_state,reward,done,_ = pp_env.step(action)
                
            
            # update action time step
            t_action = (t_action+1) % ACTION_EVERY
                
            # get total reward for the episode
            total_reward += reward

            # set current state = next_state
            state = next_state

            if done:
                break

        scores.append(total_reward)
        score_window.append(total_reward) 
        avg_scores.append(np.mean(score_window))

        print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode_count, np.mean(score_window)), len(agent.memory),end="")
        if episode_count % PRINT_EVERY == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(episode_count, np.mean(score_window)))
            eval_reward = evaluate_agent(agent)
            print("\nEpisode {}\tEval Score: {:.2f}\n".format(episode_count,eval_reward))

        if np.mean(score_window) > 13:
            print('\rLearning completed in {} episodes ... avg_score :{}'.format(episode_count, np.mean(score_window)))
            torch.save(agent.qnet_local.state_dict(), 'checkpoint_local.pth')
            break

    return agent,scores,avg_scores

# %%
# training the dqn
trained_agent,scores,avg_scores = dqn_train(max_episodes=100000,PRINT_EVERY=100)
# Out:
# Episode 100	Average Score: 0.29 1198
#
# Episode 100	Eval Score: 0.00
#
# Episode 200	Average Score: 0.25 2342
#
# Episode 200	Eval Score: 0.60
#
# Episode 300	Average Score: 0.22 3427
#
# Episode 300	Eval Score: 0.40
#
# Episode 400	Average Score: 0.39 4774
#
# Episode 400	Eval Score: 0.40
#
# Episode 500	Average Score: 0.32 5965
#
# Episode 500	Eval Score: 0.40
#
# Episode 600	Average Score: 0.33 7216
#
# Episode 600	Eval Score: 0.00
#
# Episode 700	Average Score: 0.42 8547
#
# Episode 700	Eval Score: 0.60
#
# Episode 800	Average Score: 0.38 9840
#
# Episode 800	Eval Score: 0.60
#
# Episode 900	Average Score: 0.39 11160
#
# Episode 900	Eval Score: 0.40
#
# Episode 1000	Average Score: 0.32 12339
#
# Episode 1000	Eval Score: 0.20
#
# Episode 1100	Average Score: 0.26 13463
#
# Episode 1100	Eval Score: 0.30
#
# Episode 1200	Average Score: 0.30 14693
#
# Episode 1200	Eval Score: 0.00
#
# Episode 1300	Average Score: 0.28 15849
#
# Episode 1300	Eval Score: 0.10
#
# Episode 1400	Average Score: 0.34 17056
#
# Episode 1400	Eval Score: 0.60
#
# Episode 1500	Average Score: 0.29 18185
#
# Episode 1500	Eval Score: 0.30
#
# Episode 1600	Average Score: 0.41 19484
#
# Episode 1600	Eval Score: 0.10
#
# Episode 1700	Average Score: 0.23 20634
#
# Episode 1700	Eval Score: 0.10
#
# Episode 1800	Average Score: 0.32 21823
#
# Episode 1800	Eval Score: 0.50
#
# Episode 1900	Average Score: 0.27 22981
#
# Episode 1900	Eval Score: 0.30
#
# Episode 2000	Average Score: 0.24 24122
#
# Episode 2000	Eval Score: 0.10
#
# Episode 2100	Average Score: 0.22 25224
#
# Episode 2100	Eval Score: 0.20
#
# Episode 2200	Average Score: 0.33 26464
#
# Episode 2200	Eval Score: 0.20
#
# Episode 2300	Average Score: 0.38 27896
#
# Episode 2300	Eval Score: 0.30
#
# Episode 2400	Average Score: 0.23 29021
#
# Episode 2400	Eval Score: 0.70
#
# Episode 2500	Average Score: 0.33 30235
#
# Episode 2500	Eval Score: 0.40
#
# Episode 2600	Average Score: 0.30 31421
#
# Episode 2600	Eval Score: 0.00
#
# Episode 2700	Average Score: 0.22 32491
#
# Episode 2700	Eval Score: 0.70
#
# Episode 2800	Average Score: 0.37 33794
#
# Episode 2800	Eval Score: 0.00
#
# Episode 2900	Average Score: 0.34 35068
#
# Episode 2900	Eval Score: 0.10
#
# Episode 3000	Average Score: 0.30 36268
#
# Episode 3000	Eval Score: 0.10
#
# Episode 3100	Average Score: 0.17 37332
#
# Episode 3100	Eval Score: 0.20
#
# Episode 3200	Average Score: 0.30 38510
#
# Episode 3200	Eval Score: 0.30
#
# Episode 3300	Average Score: 0.23 39595
#
# Episode 3300	Eval Score: 0.00
#
# Episode 3400	Average Score: 0.25 40744
#
# Episode 3400	Eval Score: 0.30
#
# Episode 3500	Average Score: 0.30 41959
#
# Episode 3500	Eval Score: 0.10
#
# Episode 3600	Average Score: 0.36 43243
#
# Episode 3600	Eval Score: 0.30
#
# Episode 3700	Average Score: 0.29 44434
#
# Episode 3700	Eval Score: 0.30
#
# Episode 3800	Average Score: 0.28 45596
#
# Episode 3800	Eval Score: 0.30
#
# Episode 3900	Average Score: 0.27 46750
#
# Episode 3900	Eval Score: 0.50
#
# Episode 4000	Average Score: 0.23 47843
#
# Episode 4000	Eval Score: 0.20
#
# Episode 4100	Average Score: 0.24 49009
#
# Episode 4100	Eval Score: 0.30
#
# Episode 4200	Average Score: 0.28 50199
#
# Episode 4200	Eval Score: 0.40
#
# Episode 4300	Average Score: 0.30 51377
#
# Episode 4300	Eval Score: 0.10
#
# Episode 4400	Average Score: 0.29 52567
#
# Episode 4400	Eval Score: 0.20
#
# Episode 4500	Average Score: 0.36 53839
#
# Episode 4500	Eval Score: 0.50
#
# Episode 4600	Average Score: 0.35 55119
#
# Episode 4600	Eval Score: 0.40
#
# Episode 4700	Average Score: 0.26 56292
#
# Episode 4700	Eval Score: 0.00
#
# Episode 4800	Average Score: 0.22 57380
#
# Episode 4800	Eval Score: 0.20
#
# Episode 4842	Average Score: 0.25 58006

# %%
# plotting the avg reward curve
plt.figure(figsize=(10,10))
plt.plot(range(len(avg_scores)),avg_scores)
plt.xlabel('episodes')
plt.ylabel('avg score for last 100 episodes')
plt.grid()
plt.show()

# %%
# save trained agent weights
# torch.save(agent.qnet_local.state_dict(),"checkpoint_local.pth")

# %%
# # uncomment this cell to load trained agent weights
# # initialising the agent
# trained_agent = Agent(state_size=brain.vector_observation_space_size, action_size=brain.vector_action_space_size)
# trained_agent.qnet_local.load_state_dict(torch.load('checkpoint_local.pth',map_location='cpu'))

# %%
# lets visualise at how the trained agent performs

# reset env state
env_info = env.reset(train_mode=False)[brain_name]
state = env_info.vector_observations[0]

done = env_info.local_done[0]
total_reward = 0

while not done:
    # choose action using the local q-network using low value of epsilon = 1e-2
    action = trained_agent.act(state,eps=1e-2)

    # taking action in the env
    env_info = env.step(vector_action=action)[brain_name]

    # getting next_state,reward,done from the env
    next_state = env_info.vector_observations[0]
    reward = env_info.rewards[0]
    done = env_info.local_done[0]
    
    # get total reward for the episode
    total_reward += reward
    
    # set current state = next_state
    state = next_state
    
print ("total reward : {:.2f}".format(total_reward))

# %%
# closing the environment
env.close()

# %%
m = nn.Conv2d(16, 33, 3, stride=1)
x = torch.randn(20, 16, 50, 100)
out = m(x)
out.shape

# %%
len(trained_agent.memory)

# %%
np.exp(np.log(0.1)/1e4)
